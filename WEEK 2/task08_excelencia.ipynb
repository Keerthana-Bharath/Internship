# %%
import pandas as pd
df = pd.read_csv("Downloads/orders_dirty.csv")

# %%
df.head()
# Out:
#    Order ID  Customer  Region     Category   Quantity   Unit Price   \
# 0      10001       Bob   North    Furniture        4.0       119.37
# 1      10002       Bob    West  Electronics        1.0        55.91
# 2      10003     Alice   South      Grocery        4.0       230.11
# 3      10004     Alice   South      Grocery        6.0       146.16
# 4      10005     Frank   North  Electronics        7.0        57.39
#
#   order_date   Total
# 0  23-11-2024  477.48
# 1  22-02-2024   55.91
# 2  29-04-2024  920.44
# 3  22-05-2024  876.96
# 4  20-04-2024  401.73

# %%
df.shape
# Out:
# (1150, 8)

# %%
df.columns
# Out:
# Index([' Order ID ', ' Customer ', ' Region ', ' Category ', ' Quantity ',
#        ' Unit Price ', ' order_date ', ' Total '],
#       dtype='object')

# %%
df.dtypes
# Out:
# Order ID         int64
# Customer        object
# Region          object
# Category        object
# Quantity       float64
# Unit Price     float64
# order_date      object
# Total          float64
# dtype: object

# %%
df.columns
# Out:
# Index([' Order ID ', ' Customer ', ' Region ', ' Category ', ' Quantity ',
#        ' Unit Price ', ' order_date ', ' Total '],
#       dtype='object')

# %%
#clean the cols
df.columns = (df.columns.str.strip().str.lower().str.replace(" ", "_"))
df.columns
# Out:
# Index(['order_id', 'customer', 'region', 'category', 'quantity', 'unit_price',
#        'order_date', 'total'],
#       dtype='object')

# %%
df["quantity"] = df["quantity"].astype("Int64")

# %%
df["order_date"] = pd.to_datetime(df["order_date"])
# Out:
# C:\Users\91733\AppData\Local\Temp\ipykernel_20280\4261617660.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["order_date"] = pd.to_datetime(df["order_date"])

# %%
df.dtypes
# Out:
# order_id               int64
# customer              object
# region                object
# category              object
# quantity               Int64
# unit_price           float64
# order_date    datetime64[ns]
# total                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# order_id       0
# customer       0
# region        34
# category       0
# quantity      50
# unit_price    40
# order_date     0
# total          0
# dtype: int64

# %%
df["region"] = df["region"].fillna("unknown")

# %%
df["quantity"].skew()
# Out:
# 0.03262792483175966

# %%
df["quantity"] = df["quantity"].fillna(df["quantity"].median())

# %%
df["unit_price"] = df["unit_price"].fillna(df["unit_price"].mean())

# %%
df.isnull().sum()
# Out:
# order_id      0
# customer      0
# region        0
# category      0
# quantity      0
# unit_price    0
# order_date    0
# total         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 150

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df["order_date"] = pd.to_datetime(df["order_date"])

# %%
df["order_date"]
# Out:
# 0     2024-11-23
# 1     2024-02-22
# 2     2024-04-29
# 3     2024-05-22
# 4     2024-04-20
#          ...
# 995   2024-11-19
# 996   2024-10-30
# 997   2024-11-25
# 998   2024-01-29
# 999   2024-11-30
# Name: order_date, Length: 1000, dtype: datetime64[ns]

# %%
''''df["order_date"] = df["order_date"].dt.strftime("%d-%m-%Y")
df["order_date"] to show in the required format'''
# Out:
# '\'df["order_date"] = df["order_date"].dt.strftime("%d-%m-%Y")\ndf["order_date"] to show in the required format'

# %%
#Extract date features
df["year"] = df["order_date"].dt.year
df["year"]
# Out:
# 0      2024
# 1      2024
# 2      2024
# 3      2024
# 4      2024
#        ...
# 995    2024
# 996    2024
# 997    2024
# 998    2024
# 999    2024
# Name: year, Length: 1000, dtype: int32

# %%
df["month"] = df["order_date"].dt.month
df["month"]
# Out:
# 0      11
# 1       2
# 2       4
# 3       5
# 4       4
#        ..
# 995    11
# 996    10
# 997    11
# 998     1
# 999    11
# Name: month, Length: 1000, dtype: int32

# %%
df["month"] = df["order_date"].dt.month_name()
df["month"]
# Out:
# 0      November
# 1      February
# 2         April
# 3           May
# 4         April
#          ...
# 995    November
# 996     October
# 997    November
# 998     January
# 999    November
# Name: month, Length: 1000, dtype: object

# %%
df["weekday"] = df["order_date"].dt.day_name()
df["weekday"]
# Out:
# 0       Saturday
# 1       Thursday
# 2         Monday
# 3      Wednesday
# 4       Saturday
#          ...
# 995      Tuesday
# 996    Wednesday
# 997       Monday
# 998       Monday
# 999     Saturday
# Name: weekday, Length: 1000, dtype: object

# %%
#Print null counts after cleaning
print(df.isnull().sum())
# Out:
# order_id      0
# customer      0
# region        0
# category      0
# quantity      0
# unit_price    0
# order_date    0
# total         0
# year          0
# month         0
# weekday       0
# dtype: int64

# %%
#Save the cleaned dataset
df.to_csv("orders_cleaned.csv", index=False)
